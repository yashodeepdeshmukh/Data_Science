# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
import numpy as np
from sklearn.cluster import KMeans
from sklearn import preprocessing
import pandas as pd

# %%
#Importing data set from library

# %%
df = pd.read_excel('titanic.xls')
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest           home
# 0       NaN                     St Louis, MO   St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON  Montreal, PQ
# 2       NaN  Montreal, PQ / Chesterville, ON  Montreal, PQ
# 3     135.0  Montreal, PQ / Chesterville, ON  Montreal, PQ
# 4       NaN  Montreal, PQ / Chesterville, ON  Montreal, PQ
# ...     ...                              ...            ...
# 1304  328.0                              NaN            NaN
# 1305    NaN                              NaN            NaN
# 1306  304.0                              NaN            NaN
# 1307    NaN                              NaN            NaN
# 1308    NaN                              NaN            NaN
#
# [1309 rows x 15 columns]

# %%
#data cleaning

# %%
df[['boat','home','cabin','fare']]=df[['boat','home','cabin','fare']].fillna(0)
df.dropna(subset=['age'], inplace=True)
clean=df.drop(['name','body','ticket','home.dest'],1,inplace=False)

# %%
clean
# Out:
#       pclass  survived     sex      age  sibsp  parch      fare    cabin  \
# 0          1         1  female  29.0000      0      0  211.3375       B5
# 1          1         1    male   0.9167      1      2  151.5500  C22 C26
# 2          1         0  female   2.0000      1      2  151.5500  C22 C26
# 3          1         0    male  30.0000      1      2  151.5500  C22 C26
# 4          1         0  female  25.0000      1      2  151.5500  C22 C26
# ...      ...       ...     ...      ...    ...    ...       ...      ...
# 1301       3         0    male  45.5000      0      0    7.2250        0
# 1304       3         0  female  14.5000      1      0   14.4542        0
# 1306       3         0    male  26.5000      0      0    7.2250        0
# 1307       3         0    male  27.0000      0      0    7.2250        0
# 1308       3         0    male  29.0000      0      0    7.8750        0
#
#      embarked boat           home
# 0           S    2   St Louis, MO
# 1           S   11  Montreal, PQ
# 2           S    0  Montreal, PQ
# 3           S    0  Montreal, PQ
# 4           S    0  Montreal, PQ
# ...       ...  ...            ...
# 1301        C    0              0
# 1304        C    0              0
# 1306        C    0              0
# 1307        C    0              0
# 1308        S    0              0
#
# [1046 rows x 11 columns]

# %%
#data_conversion

# %%
def handle_non_numerical_data(clean):
    columns = clean.columns.values

    for column in columns:
        text_digit_vals = {}
        def convert_to_int(val):
            return text_digit_vals[val]

        if clean[column].dtype != np.int64 and clean[column].dtype != np.float64:
            column_contents = clean[column].values.tolist()
            unique_elements = set(column_contents)
            x = 0
            for unique in unique_elements:
                if unique not in text_digit_vals:
                    text_digit_vals[unique] = x
                    x+=1

            clean[column] = list(map(convert_to_int, clean[column]))

    return clean
clean = handle_non_numerical_data(clean)

# %%
#Kmeans

# %%
X = np.array(clean.drop(['survived'], 1).astype(float))
y = np.array(clean['survived'])

# %%
clf = KMeans(n_clusters=2)

# %%
clf.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
#check probability

# %%
correct = 0
for i in range(len(X)):
    predict_me = np.array(X[i].astype(float))
    predict_me = predict_me.reshape(-1, len(predict_me))
    prediction = clf.predict(predict_me)
    if prediction[0] == y[i]:
        correct += 1

print(correct/len(X))
# Out:
# 0.4168260038240918
